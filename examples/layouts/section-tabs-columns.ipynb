# %%
flex_author = "built using jupyter-flex"
flex_source_code = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/section-tabs-columns.ipynb"

# %% [markdown]
# ## Column 1

# %% [markdown]
# ### First

# %%
1

# %% [markdown]
# ### Second

# %%
2

# %% [markdown]
# ## Column 2

# %% [markdown]
# ### A

# %%
"A"

# %% [markdown]
# ### B

# %%
"B"

# %% [markdown]
# ### C

# %%
"C"
