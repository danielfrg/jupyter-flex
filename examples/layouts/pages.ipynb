# %%
flex_author = "built using jupyter-flex"
flex_source_code = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/pages.ipynb"

# %% [markdown]
# # Page 1

# %% [markdown]
# ## Col 1

# %%
"Page 1 - Col 1"

# %% [markdown]
# ## Col 2

# %% [markdown]
# ### Col 2 - Tab 1

# %%
"Page 1 - Col 2 - Tab 1"

# %% [markdown]
# ### Col 2 - Tab 2

# %%
"Page 1 - Col 2 - Tab 2"

# %% [markdown]
# # Page 2

# %% [markdown]
# ## Row 1

# %% [markdown]
# ### Page 2 - Row 1 - Tab 1

# %%
"Page 2 - Row 1 - Tab 1"

# %% [markdown]
# ### Page 2 - Row 1 - Tab 2

# %%
"Page 2 - Row 1 - Tab 2"

# %% [markdown]
# ## Row 2

# %%
"Page 1 - Row 2"
