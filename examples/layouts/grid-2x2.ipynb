# %%
flex_subtitle = "built using jupyter-flex"
flex_external_link = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/grid-2x2.ipynb"

flex_homepage_link = "https://jupyter-flex.danielfrg.com"
flex_show_source = True

# %% [markdown]
# ## Column 1

# %% [markdown]
# ### Col 1 - Card 1

# %%
# <code>

# %% [markdown]
# ### Col 1 - Card 2

# %%
# <code>

# %% [markdown]
# ## Column 2

# %% [markdown]
# ### Col 2 - Card 1

# %%
# <code>

# %% [markdown]
# ### Col 2 - Card 2

# %%
# <code>
