# %%
flex_orientation = "rows"
flex_subtitle = "built using jupyter-flex"
flex_external_link = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/focal-chart-top-card-size.ipynb"

# %% [markdown]
# ## Row 1

# %% [markdown]
# ### Row 1

# %%
# <code>

# %% [markdown]
# ## Row 2

# %% [markdown]
# ### Row 2 - Card 1

# %%
# <code>

# %% [markdown]
# ### Row 2 - Card 1

# %%
# <code>
