# %%
flex_orientation = "rows"
flex_author = "built using jupyter-flex"
flex_source_code = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/grid-2x3.ipynb"

# %% [markdown]
# ## Column 1

# %% [markdown]
# ### Subplot 1-1

# %%
# code

# %% [markdown]
# ### Subplot 1-2

# %%
# code

# %% [markdown]
# ## Column 2

# %% [markdown]
# ### Subplot 2-1

# %%
# code

# %% [markdown]
# ### Subplot 2-2

# %%
# code

# %% [markdown]
# ### Subplot 2-3

# %%
# code
