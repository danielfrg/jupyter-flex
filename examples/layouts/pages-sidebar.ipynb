# %%
flex_source_code = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/layouts/pages-sidebar.ipynb"

# %% [markdown]
# # Sidebar

# %% [markdown]
# ### Header 1

# %% [markdown]
# This is some text!

# %% [markdown]
# ### Header 2

# %% [markdown]
# More stuff

# %% [markdown]
# # Page 1

# %% [markdown]
# Page 1 text

# %%
"Page 1 code"

# %% [markdown]
# # Page 2

# %% [markdown]
# Page 2 text

# %%
"Page 2 code"
