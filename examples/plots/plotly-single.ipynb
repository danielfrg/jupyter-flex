# %%
flex_title = "Plotly single"
flex_author = "built using jupyter-flex"
flex_source_code = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/plots/plotly-single.ipynb"

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
margin = go.layout.Margin(l=20, r=20, b=20, t=30)

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length")

fig.update_layout(margin=margin)
fig
