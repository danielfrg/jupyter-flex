# %%
flex_subtitle = "built using jupyter-flex"
flex_external_link = "https://github.com/danielfrg/jupyter-flex/blob/master/examples/customize/custom-css-nbconvert.ipynb"

flex_title = "A dashboard using a custom.css file"\
# Paths for nbconvert (directly on this directory)
flex_custom_css = "customize/custom.css"
# flex_favicon = "customize/favicon.png"
# flex_logo = "customize/logo.png"

# %% [markdown]
# # Page

# %% [markdown]
# ## Section 1

# %% [markdown]
# The `custom.css` file is:
#
# ```
# .jupyter-flex .navbar {
#     background-color: blue;
# }
#
# .page {
#     background-color: red;
# }
#
# .section {
#     background-color: green;
# }
#
# .card {
#     background-color: #bbbb70;
# }
# ```

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Plot 1

# %%
# <code>

# %% [markdown]
# ### Plot 2

# %%
# <code>

# %% [markdown]
# ### Plot 3

# %%
# <code>
